# %%
import numpy as np
import pandas as pd
import os
import re
import string

# %%
df1 = pd.read_csv(r'C:\\Nayan\\Programming\\.vscode\\DPC_sir_project\\newdata\\S08_question_answer_pairs.txt',encoding='latin-1',sep='\t')
df2 = pd.read_csv(r'C:\\Nayan\\Programming\\.vscode\\DPC_sir_project\\newdata\\S09_question_answer_pairs.txt',encoding='latin-1',sep='\t')
df3 = pd.read_csv(r'C:\\Nayan\\Programming\\.vscode\\DPC_sir_project\\newdata\\S10_question_answer_pairs.txt',encoding='latin-1',sep='\t')
df = pd.concat([df1,df2,df3],ignore_index=True)

# %%
df.head()
# Out:
#    ï»¿ArticleTitle                                           Question Answer  \
# 0  Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...    yes
# 1  Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...   Yes.
# 2  Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...    yes
# 3  Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...   Yes.
# 4  Abraham_Lincoln                   Did his mother die of pneumonia?     no
#
#   DifficultyFromQuestioner DifficultyFromAnswerer  ArticleFile ArticleTitle
# 0                     easy                   easy  S08_set3_a4          NaN
# 1                     easy                   easy  S08_set3_a4          NaN
# 2                     easy                 medium  S08_set3_a4          NaN
# 3                     easy                   easy  S08_set3_a4          NaN
# 4                     easy                 medium  S08_set3_a4          NaN

# %%
df = df.rename(columns={'ï»¿ArticleTitle' : 'intents'})

# %%
# pd.set_option('display.max_rows', None)
df
# Out:
#               intents                                           Question  \
# 0     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 1     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 2     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 3     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 4     Abraham_Lincoln                   Did his mother die of pneumonia?
# ...               ...                                                ...
# 3993              NaN          What areas do the Grevy's Zebras inhabit?
# 3994              NaN  Which species of zebra is known as the common ...
# 3995              NaN  Which species of zebra is known as the common ...
# 3996              NaN                     At what age can a zebra breed?
# 3997              NaN                     At what age can a zebra breed?
#
#                                                  Answer  \
# 0                                                   yes
# 1                                                  Yes.
# 2                                                   yes
# 3                                                  Yes.
# 4                                                    no
# ...                                                 ...
# 3993                                                NaN
# 3994  Plains Zebra (Equus quagga, formerly Equus bur...
# 3995                                       Plains Zebra
# 3996                                        five or six
# 3997                                             5 or 6
#
#      DifficultyFromQuestioner DifficultyFromAnswerer  ArticleFile ArticleTitle
# 0                        easy                   easy  S08_set3_a4          NaN
# 1                        easy                   easy  S08_set3_a4          NaN
# 2                        easy                 medium  S08_set3_a4          NaN
# 3                        easy                   easy  S08_set3_a4          NaN
# 4                        easy                 medium  S08_set3_a4          NaN
# ...                       ...                    ...          ...          ...
# 3993                     hard                    NaN  S10_set1_a9        Zebra
# 3994                     hard                 medium  S10_set1_a9        Zebra
# 3995                     hard                 medium  S10_set1_a9        Zebra
# 3996                     hard                 medium  S10_set1_a9        Zebra
# 3997                     hard                   hard  S10_set1_a9        Zebra
#
# [3998 rows x 7 columns]

# %%
# df = df.dropna()
df = df.drop(['DifficultyFromQuestioner', 'DifficultyFromAnswerer', 'ArticleFile', 'ArticleTitle'], axis = 1)

# %%
df = df.dropna(subset=['Answer'])

# %%
df
# Out:
#               intents                                           Question  \
# 0     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 1     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 2     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 3     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 4     Abraham_Lincoln                   Did his mother die of pneumonia?
# ...               ...                                                ...
# 3992              NaN          What areas do the Grevy's Zebras inhabit?
# 3994              NaN  Which species of zebra is known as the common ...
# 3995              NaN  Which species of zebra is known as the common ...
# 3996              NaN                     At what age can a zebra breed?
# 3997              NaN                     At what age can a zebra breed?
#
#                                                  Answer
# 0                                                   yes
# 1                                                  Yes.
# 2                                                   yes
# 3                                                  Yes.
# 4                                                    no
# ...                                                 ...
# 3992  semi-arid grasslands of Ethiopia and northern ...
# 3994  Plains Zebra (Equus quagga, formerly Equus bur...
# 3995                                       Plains Zebra
# 3996                                        five or six
# 3997                                             5 or 6
#
# [3422 rows x 3 columns]
